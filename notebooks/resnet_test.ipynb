# %% [markdown]
# ### Resnet

# %%
from preprocess.preprocessor import Preprocessor
from models.resnet_custom import ResnetCustom
import torch
import os

# %%
SPLIT_DIR = "/home/joaorodriguesz/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/data/split"
SAVED_MODELS_DIR = "/home/joaorodriguesz/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/saved_models"
DEVICE    = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
pre = Preprocessor()

# Carrega amostras e rótulos
train_samples, train_labels, idx2lbl = pre._collect_samples(os.path.join(SPLIT_DIR, "train"))
val_samples, val_labels, _           = pre._collect_samples(os.path.join(SPLIT_DIR, "val"))
test_samples, test_labels, _         = pre._collect_samples(os.path.join(SPLIT_DIR, "test"))

# Loaders
train_loader = pre._make_loader(list(zip(train_samples, train_labels)), batch_size=10, shuffle=True)
val_loader   = pre._make_loader(list(zip(val_samples, val_labels)), batch_size=10, shuffle=False)
test_loader  = pre._make_loader(list(zip(test_samples, test_labels)), batch_size=10, shuffle=False)

model = ResnetCustom(num_classes=len(idx2lbl))
model.train_model(train_loader, val_loader, idx2lbl, device=DEVICE, epochs=25)
model.evaluate(test_loader, idx2lbl, DEVICE, "TESTE FINAL")
model_save_path = os.path.join(SAVED_MODELS_DIR, "resnet_cnn_trained_v2.pth")
model.save_model(model_save_path)
# Out:
# /home/joaorodriguesz/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/src/models/resnet_custom.py:45: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = GradScaler()
# /home/joaorodriguesz/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torch/amp/grad_scaler.py:136: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# 📊 Balanceamento no treino:
#  - H: 28 exemplo(s)
#  - J: 28 exemplo(s)
#  - K: 28 exemplo(s)
#  - X: 28 exemplo(s)
#  - Y: 20 exemplo(s)
#  - Z: 28 exemplo(s)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 14
#      11 test_loader  = pre._make_loader(list(zip(test_samples, test_labels)), batch_size=10, shuffle=False)
#      13 model = ResnetCustom(num_classes=len(idx2lbl))
# ---> 14 model.train_model(train_loader, val_loader, idx2lbl, device=DEVICE, epochs=25)
#      15 model.evaluate(test_loader, idx2lbl, DEVICE, "TESTE FINAL")
#      16 model_save_path = os.path.join(SAVED_MODELS_DIR, "resnet_cnn_trained_v2.pth")
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/src/models/resnet_custom.py:89, in ResnetCustom.train_model(self, train_loader, val_loader, idx2lbl, device, epochs, lr)
#      87     self.scaler.update()
#      88 else:
# ---> 89     out = self(x)
#      90     loss = criterion(out, y)
#      91     loss.backward()
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/src/models/resnet_custom.py:50, in ResnetCustom.forward(self, x)
#      48 B, T, H, W = x.shape
#      49 x = x.view(B * T, 1, H, W)
# ---> 50 x = self.backbone(x)
#      51 x = self.classifier(x)
#      52 x = x.view(B, T, -1).mean(dim=1)
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torch/nn/modules/container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torch/nn/modules/container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torchvision/models/resnet.py:96, in BasicBlock.forward(self, x)
#      93 out = self.bn1(out)
#      94 out = self.relu(out)
# ---> 96 out = self.conv2(out)
#      97 out = self.bn2(out)
#      99 if self.downsample is not None:
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/dev/workspace/github/dynamic-signs-recognition-libras-alphabet-cnn/venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
